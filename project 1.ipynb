# %%
# project 1: Unit of measurement converter-  lets take inputs from the system using input function

convert_from = input("Enter unit of measurement (inches, feet, yards): ")
convert_to = input("Enter unit of measurement to convert to(inches, feet, yards): ")
number_of_inches = input("Enter measurement in Inches: ")
number_of_feets = input("Enter measurement in feet: ")
number_of_yards = input("Enter measurement in Yards: ")
# Out:
# Enter unit of measurement (inches, feet, yards):  inches
# Enter unit of measurement to convert to(inches, feet, yards):  feet
# Enter measurement in Inches:  5
# Enter measurement in feet:  6
# Enter measurement in Yards:  3

# %%
convert_from = input("Enter unit of measurement (inches, feet, yards): ")
convert_to = input("Enter unit of measurement to convert to(inches, feet, yards): ")

if convert_from.lower() in ['inches', 'inch', 'in']:
    number_of_inches = int(input("Enter measurement in Inches: "))
    if convert_to.lower() in ['feet', 'foot', 'ft']:
        print('result : ' +str(number_of_inches) + ' Inches = ' + str(round(number_of_inches / 12)) + 'feet')

    elif convert_to.lower() in ['yards', 'yds', 'yd']:
        print('result : ' +str(number_of_inches) + ' Inches = ' + str(round(number_of_inches / 36)) + 'yards')

    else:
        print('input is wrong')
        
elif convert_from.lower() in ['feet', 'feets', 'foot', 'ft', 'fts']:
    number_of_feets = int(input("Enter measurement in feets: "))
    if convert_to.lower() in  ['inches', 'inch', 'in']:
        print('result : ' +str(number_of_feets) + ' feet = ' + str(round(number_of_feets * 12)) + 'inches')

    elif convert_to.lower() in  ['yards','yds','yard']:
         print('result : ' +str(number_of_feets) + ' feet = ' + str(round(number_of_feets / 3)) + 'yards')

    else:
        print('input is wrong')

elif convert_from.lower() in  ['yards', 'yard', 'yd', 'yds']:
    number_of_yards = int(input("Enter measurement in Yards: "))
    if convert_to.lower() in ['inches', 'inch', 'in']:
        print('result : ' +str(number_of_yards) + ' Yards = ' + str(round(number_of_yards * 36)) + 'inches')

        print(number_of_yards * 36)
    elif convert_to.lower() in ['feet', 'foot', 'ft']:
        print('result : ' +str(number_of_yards) + ' yards = ' + str(round(number_of_yards * 12)) + 'feet')

        print(number_of_yards * 3)
    else:
        print("input is wrong")
# Out:
# Enter unit of measurement (inches, feet, yards):  in
# Enter unit of measurement to convert to(inches, feet, yards):  ft
# Enter measurement in Inches:  98
# result: 98Inches = 8feet
